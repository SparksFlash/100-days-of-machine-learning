# %%
import pandas as pd
import requests                 # HTTP requests library
from bs4 import BeautifulSoup   # Web scraping library
import numpy as np

# %% [markdown]
# # if response code is 403
#  - headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
#  -requests.get('url',headers=headers).text

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://www.zomato.com/kolkata',headers=headers).text
# #webpage=requests.get('').text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://googleads.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://jumbo.zomato.com" rel="preconnect"/>
#   <link href="https://accounts.google.com" rel="preconnect"/>
#   <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#   <link href="https://www.google-analytics.com" rel="preconnect"/>
#   <link href="https://www.googleadservices.com" rel="preconnect"/>
#   <link href="https://bat.bing.com" rel="preconnect"/>
#   <link href="https://8391443.fls.doubleclick.net" rel="preconnect"/>
#   <title data-rh="true">
#    Best Restaurants in India - Zomato
#   </title>
#   <meta charset="utf-8" data-rh="true"/>
#   <meta content="NOODP,NOYDIR" data-rh="true" name="robots"/>
# ...

# %%
soup.find_all('h2')[0].text   # Find the first h2 tag and get its text
                              # Here [0] is the index of the first h2 tag

# len(soup.find_all('div'))      # Use len() to count the number of h1 tags
# Out:
# 'Dining Out'

# %% [markdown]
# # TO FIND OUT NAMES OF THE RESTURANTS FROM ZOMATO

# %%
for i in soup.find_all('h4'):
  print(i.text.strip())
# Out:
# Fabbrica Originale
# Eden Courtyard
# Lucky Tigerr
# Boujee House
# Yarana Supper Club
# Tall Tales
# Junglee Cafe Mystique
# Darlings
# Cal - On

# %%
for i in soup.find_all('p'):   # Find all p tags and iterate through them
  print(i.text.strip())
# Out:
# Detect current location
# Using GPS
# Top Trending Spots
# Sky High Sips
# Insta-worthy Spots
# Must Visit Cafes
# Best Pubs & Bars
# Best Buffets In Town
# Premium Coffee Shops
# Top Breakfast Spots
# Italian, Pizza, Pasta, Desserts, Coffee, Beverages
# ₹1,200 for two
# Park Street Area, Kolkata
# 2.5 km
# Modern Indian, Italian, Asian
# ₹1,500 for two
# Kankurgachi, Kolkata
# 3.8 km
# Asian
# ₹1,500 for two
# Park Street Area, Kolkata
# 2.6 km
# Italian, Continental
# ₹2,500 for two
# Park Street Area, Kolkata
# 2.6 km
# North Indian, Continental, Chinese
# ₹2,000 for two
# Sector 1, Salt Lake, Kolkata
# 4.9 km
# Modern Indian, Continental, North Indian, Chinese
# ₹2,500 for two
# Camac Street Area, Kolkata
# 3.4 km
# Continental, Chinese, North Indian
# ₹1,000 for two
# Sector 1, Salt Lake, Kolkata
# 4.4 km
# Chinese, North Indian
# ₹2,500 for two
# Camac Street Area, Kolkata
# 3.1 km
# Asian, Pizza, Parsi, North Indian, Desserts
# ₹3,000 for two
# Ballygunge, Kolkata
# ...

# %%
#for in soup.find_all('p'):
  #print(i.text.strip())

# %% [markdown]
# ## TO FIND OUT THE RATINGS

# %%
for div in soup.find_all(class_= 'sc-1q7bklc-1 cILgox'):
    print(div.text.strip())
# Out:
# 4.6
# 4.3
# New
# 4.0
# 4.5
# 4.1
# 4.3
# 4.3
# 4.5

# %% [markdown]
# ## TO FIND OUT THE NUMBER OF REVIEWS

# %%
len(soup.find_all('div' , class_= 'sc-1q7bklc-1 cILgox'))
# Out:
# 9

# %% [markdown]
# # CONSIDERING THE WHOLE CONTAINER

# %%
hotel = soup.find_all('div',class_='sc-1mo3ldo-0 sc-gYtlsd gktbto')

# for div in soup.find_all(class_= 'min-basic-info-right'):
#     print(div.text.strip())

# %%
len(hotel)
# Out:
# 0

# %%
name=[]
rating=[]
reviews=[]
ctype=[]
hq=[]
how_old=[]
no_of_employee=[]

for i in company:

  name.append(i.find('h2').text.strip())
  rating.append(i.find('p',class_='rating').text.strip())
  reviews.append(i.find('a' , class_='review-count').text.strip())
  ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
  hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
  how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
  no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())

df=pd.DataFrame({'name':name,
   'rating':rating,
   'reviews':reviews,
   'company_type':ctype,
   'Head_Quarters':hq,
   'Company_Age':how_old,
   'No_of_Employee':no_of_employee,
   })

# %%
name
# Out:
# []

# %%
rating
# Out:
# []

# %%
reviews
# Out:
# []

# %%
ctype
# Out:
# []

# %%
hq
# Out:
# []

# %%
how_old
# Out:
# []

# %%
no_of_employee
# Out:
# []

# %%
df.shape
# Out:
# (0, 7)

# %% [markdown]
# # creating dataframe for all the pages

# %%
final=pd.DataFrame()
for j in range(1,1001):
  webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page={}'.format(j)).text
  soup=BeautifulSoup(webpage,'lxml')
  company=soup.find_all('div',class_='company-content-wrapper')
  name=[]
  rating=[]
  reviews=[]
  ctype=[]
  hq=[]
  how_old=[]
  no_of_employee=[]

  for i in company:

    try:
       name.append(i.find('h2').text.strip())
    except:
       name.append(np.nan)

    try:
       rating.append(i.find('p',class_='rating').text.strip())
    except:
       rating.append(np.nan)
   
    try:

      reviews.append(i.find('a' , class_='review-count').text.strip())
    except:
      reviews.append(np.nan)

    try:

      ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
    except:
      ctype.append(np.nan)
    try:

      hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
    except:
      hq.append(np.nan)
    
    try:

      how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
    except:
      how_old.append(np.nan)
    try:
      no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())
    except:
      no_of_employee.append(np.nan)
    

  df=pd.DataFrame({'name':name,
    'rating':rating,
    'reviews':reviews,
    'company_type':ctype,
    'Head_Quarters':hq,
    'Company_Age':how_old,
    'No_of_Employee':no_of_employee,
    })
  
  final=final.append(df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 3
#       1 final=pd.DataFrame()
#       2 for j in range(1,1001):
# ----> 3   webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page={}'.format(j)).text
#       4   soup=BeautifulSoup(webpage,'lxml')
#       5   company=soup.find_all('div',class_='company-content-wrapper')
#
# File /usr/lib/python3.13/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /usr/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
# ...

# %%
df.sample(5)
# Out:
#                            name rating  ...    Company_Age    No_of_Employee
# 2               Bank of America    4.3  ...   22 years old  10000+ employees
# 22               R.R. Donnelley    4.1  ...  156 years old  10000+ employees
# 11  Mahindra Holidays & Reso...    3.9  ...   24 years old  10000+ employees
# 23  GVK Emergency Management...    3.9  ...   15 years old  10000+ employees
# 9            Itc Infotech India    3.4  ...   20 years old  10000+ employees
#
# [5 rows x 7 columns]

# %%
df.shape
# Out:
# (30, 7)

# %%
final.shape
# Out:
# (30000, 7)
