# %%
import pickle
import numpy as np
import joblib

# %%
ohe_sex = pickle.load(open('model/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('model/ohe_embarked.pkl','rb'))
# clf = pickle.load(open('model/clf.pkl','rb'))
# save model
joblib.dump(clf, "model/clf.pkl")

# load model (alternate of pickle.load)
clf = joblib.load("model/clf.pkl")

# %%
# Assume user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
# Upgrade scikit-learn to latest version to fix '_infrequent_enabled' erro

# test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))

from sklearn.preprocessing import OneHotEncoder

# create new OneHotEncoder in sklearn 1.7.1
ohe_sex = OneHotEncoder(sparse_output=False, handle_unknown='ignore')

# # fit it again on your training data
# ohe_sex.fit(X_train[['Sex']])

# now you can safely transform test data
test_input_sex = ohe_sex.transform(test_input[:, 1].reshape(1, -1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 11
#       8 ohe_sex = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
#      10 # # fit it again on your training data
# ---> 11 ohe_sex.fit(X_train_transformed[['Sex']])
#      13 # now you can safely transform test data
#      14 test_input_sex = ohe_sex.transform(test_input[:, 1].reshape(1, -1))
#
# NameError: name 'X_train_transformed' is not defined

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %%
clf.predict(test_input_transformed)
# Out:
# array([1], dtype=int64)
